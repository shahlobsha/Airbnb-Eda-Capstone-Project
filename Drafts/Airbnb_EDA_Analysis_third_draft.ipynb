# %% [markdown]
# <a href="https://colab.research.google.com/github/shahlobsha/Airbnb-Eda-Capstone-Project/blob/main/Drafts/Airbnb_EDA_Analysis_third_draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Airbnb EDA Analysis
#
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Dobe by**         - Shahlob V S

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ![1_yZ1LPIcXnnW6Ubmp2M-0rQ.png](data:image/png;base64,...)

# %% [markdown]
# **Airbnb** is a prominent online hospitality marketplace connecting travelers with lodging options worldwide. Founded in 2008, it has revolutionized travel by enabling individuals to rent a variety of accommodations directly from hosts. This sharing economy platform offers unique stays, ranging from cozy homes to unconventional spaces. Airbnb has created a global community of hosts and travelers, providing diverse and cost-effective lodging choices. While it's transformed the way people travel, Airbnb has also faced regulatory challenges, housing concerns, and community impacts in some regions due to its disruptive influence on traditional hospitality and housing markets.
#
#
# The project focuses on conducting exploratory data analysis (EDA) on Airbnb data from New York City in 2019. This analysis aims to gain insights into the Airbnb market in NYC, explore patterns and trends, and provide valuable information for hosts, travelers, and potential investors.
#
# Key Objectives:
#
#
# 1. **Understand Market Dynamics:** The project intends to comprehend the dynamics of the Airbnb market in NYC. This includes identifying peak booking seasons, pricing trends, and the types of properties available for rental.
#
# 2. **Geospatial Analysis**: Utilizing geospatial data, the analysis will explore the distribution of listings across different neighborhoods in NYC. This will help uncover which areas are most popular among Airbnb users.
#
# 3. **Pricing Strategies:** The study will delve into how hosts price their listings. It will analyze factors such as property type, neighborhood, and the impact of different amenities on pricing.
#
# 4. **Property Types:** By categorizing and analyzing various property types (e.g., apartments, houses, private rooms), the analysis will provide insights into the most common types of listings and their respective demand.
#
#
# The analysis was conducted to gain insights into the factors influencing Airbnb prices in New York City and to discover patterns among all variables. This endeavor aimed to provide valuable information for both travelers and hosts in the city while offering insights for the Airbnb business.
#
# The project involved the meticulous exploration and cleaning of the dataset to ensure its readiness for analysis. This encompassed a deep dive into understanding the dataset's characteristics, including data types, identification of missing values, and the distribution of data. The cleaning process was equally rigorous, addressing issues such as data errors, missing values and duplicate entries.
#
# After the dataset's meticulous preparation, we proceeded to explore and summarize it by describing the data, creating data visualizations, and identifying underlying patterns and trends.
#
# Data visualization was a fundamental tool in uncovering and understanding Airbnb data patterns. We harnessed graphs and charts to visually represent the dataset and appended valuable insights and observations under each visualization. This approach facilitated a deeper comprehension of the data and allowed for the identification of pertinent insights and patterns that might have remained concealed within the raw data.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
#import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
airbnb_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Almabetter/Csv datasets/Airbnb NYC 2019 (1).csv") #reading the csv file from the google drive

# %% [markdown]
# ### Dataset First View

# %%
airbnb_df.head() #this will display the first 5 rows of data
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
airbnb_df.shape # There are 48895 rows and 16 columns
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %% [markdown]
# #### Duplicate Values

# %%
airbnb_df.duplicated().sum() #to check for duplicates
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
airbnb_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(airbnb_df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains information about **48,895 rows** of Airbnb listings in New York City with **16 columns**. This will help us to analyze the data in order to get useful insights for the company which can help to make better decisions.
#
# The Data which i have analyzed have some discrepancies where we have to make sure it stays perfect. We need to change the data type for columns named **price** and **last_review** because they are **int64** and **object**. The price must be changed to float and the date column also to be changed to date datatype
#
# **Null Values**
#
# 1. *name*              - 16
# 2. *host_name*         - 21
# 3. *last_review*       - 10052
# 4. *reviews_per_month* - 10052
#
# The above visualization shows that there are null values. We probably need to do data wrangling to make sure to remove null values so that the data looks clean.

# %% [markdown]
# As there are only few names and host_name under null values, we can substitute the null value with unknown. However for last_review column, we can substitute with number 0 because there are no reviews given based on the data given in number_of_reviews column. We will be doing this under data wrangling section.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Dataset Describe
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %% [markdown]
# ### Variables Description
#
# 1. **id**                           - The listing id
# 2. **name**                           - The listing name
# 3. **host_id**                     - The id of the person who hosts out their property
# 4. **host_name**                      - The name of the host who has lists the property
# 5. **neighbourhood_group**            - The name of the counties in newyork city
# 6. **neighbourhood**                   - Lists of neighbours under the counties of new york city
# 7. **latitude**                        - Numerical format which shows the location of place
# 8. **longitude**                       - Numerical format which shows the location of place
# 9. **room_type**                      - Room type shows which type of room that the apartment is rented. i.e:- Private room, entire home etc
# 10. **price**                          - The price of the property for rent
# 11. **minimum_nights**                 - Show the minimum number of nights that the guest must stay.
# 12. **number_of_reviews**              - Shows the number of review for the property
# 13. **last_review**                    - Shows the last date of review
# 14. **reviews_per_month**              - The reviews given by customer per month
# 15. **calculated_host_listings_count** - Shows the count of listing given by the host
# 16. **availability_365**               - Shows how many days the property is available in a year

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
airbnb_df.nunique() #shows the number of unique values for all columns
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
airbnb_df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#changing data type of price and last_review
airbnb_df['price']=airbnb_df['price'].astype(float)
airbnb_df['last_review']=pd.to_datetime(airbnb_df['last_review'])

# %%
airbnb_df[['name', 'host_name']] = airbnb_df[['name', 'host_name']].fillna('unknown')  #substituting null values with 'unknown'
airbnb_df[['reviews_per_month']] = airbnb_df[['reviews_per_month']].fillna(0) #substituting null values with 0

# %%
#Filter unknown names where rating is 0
u_name = airbnb_df[(airbnb_df['name'] == 'unknown') & (airbnb_df['number_of_reviews'] == 0)]

# %%
# #dropping the rows where name are unknown and rating is 0.
indices = u_name.index
airbnb_df.drop(indices,inplace = True)

# %%
#using mode to find the the price which is 0
mod_1 = airbnb_df['price'].mode()

#replacing value 0 with mode value
airbnb_df['price'].replace(0,mod_1[0],inplace=True)

# %%
#Finding the mean from the availability column

mean_1 = airbnb_df['availability_365'].mean()
mean_1
# Out:
# 112.78952643960315

# %%
#filling out the 0 values with mean under availability column with rounded figure
airbnb_df['availability_365'].replace(0,round(mean_1),inplace=True)

# %%
#to check outliers in the price section
sns.boxplot(data=airbnb_df, y='price')
# Out:
# <Axes: ylabel='price'>

# %%
#to remove the outliers
airbnb_df= airbnb_df[(airbnb_df['price'] >= airbnb_df['price'].quantile(0.05)) &
(airbnb_df['price'] <= airbnb_df['price'].quantile(0.95))]

# %% [markdown]
# ### What all manipulations have you done and insights you found?
#
# 1. The **price** and **last_review** column had wrong datatype. I have changed the price from int to float because mostly the price may vary as timne changes and it might not be displayed probably as whole number.
#
#   The **last_review** was object data types and the values were date. So the best approach is to change the datatype from object to datetime.
#
# 2. Few names and host_name had null values. In order to remove the null values. As null data has values to other columns, i have changed the null to unknown to not delete these datas
#
# 3. The **last_review** and **reviews_per_month** columns have large number of null values which is about 10000. So I have replaced the blanks with 0
#
# 4. I have filtered the unknown **names** and **number_of_reviews** column with the value 0. As both are having null values, i have dropped 10 values.
#
# 5. Under the price column, there were plenty of values which were 0. So in order to fill the values, I calculated the mode of price and replaced the 0 with **mode** value
#
# 6. In **Availability_365** column, there were plenty of values which were 0. So the best approach i have taken is to find the mean of the column and replace the 0 with **mean** value
#
# 7. There were plenty of outliers in the price section. So i have removed the outliers using quantile technique.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
airbnb_df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room  149.0               1                  9  2018-10-19
# 1  Entire home/apt  225.0               1                 45  2019-05-21
# 2     Private room  150.0               3                  0         NaT
# 3  Entire home/apt   89.0               1                270  2019-07-05
# 4  Entire home/apt   80.0              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2               0.00                               1               365
# 3               4.64                               1               194
# 4               0.10                               1               113

# %% [markdown]
# #### Chart - 1
# ### Average Room-Rent Rates on different boroughs

# %%
# Chart - 1 visualization code
mean_1 = airbnb_df.groupby(['neighbourhood_group', 'room_type'])['price'].mean().reset_index() #finding the average rental rate on different borough and room-type
mean_1
# Out:
#    neighbourhood_group        room_type       price
# 0                Bronx  Entire home/apt  115.022099
# 1                Bronx     Private room   67.224762
# 2                Bronx      Shared room   65.034483
# 3             Brooklyn  Entire home/apt  151.468498
# 4             Brooklyn     Private room   73.781557
# 5             Brooklyn      Shared room   74.786982
# 6            Manhattan  Entire home/apt  186.435453
# 7            Manhattan     Private room  100.943361
# 8            Manhattan      Shared room   86.611111
# 9               Queens  Entire home/apt  133.471140
# 10              Queens     Private room   70.043886
# 11              Queens      Shared room   68.988235
# 12       Staten Island  Entire home/apt  121.089286
# 13       Staten Island     Private room   71.333333
# 14       Staten Island      Shared room   98.750000

# %%
plt.figure(figsize=(7,5)) #changing the size of the figure
sns.set(palette='muted', style='ticks')
sns.barplot(data=mean_1, x='neighbourhood_group', y='price', hue='room_type')

plt.xlabel("Neighbourhood Group")
plt.ylabel("Price")
plt.title("Average room rent rate on different Boroughs", fontweight='bold')
plt.legend(fontsize=10)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# This data in this chart includes categorical variables which are neighbiourhood groups and room-types. Stacked bar chart will be the best option for data visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# * From this chart, we can understand that the average room rent rate will be higher for Entire home/apartment as compared to other room-types.
# * The average rental rate is higher on manhattan side as compared to other neighbour groups

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# With this visualization, we can understand that the room rent is higher on manhattan borough. Based on my intution, we can consider that higher income people would be living here. So one negative lead is that the middle class and average income group might probably not prefer here to stay in Manhattan. They would prefer to stay other boroughs.

# %% [markdown]
# #### Chart - 2
# ### Number of properties listing on different Boroughs

# %%
host_list_count= airbnb_df.groupby(['neighbourhood_group'])[['host_name']].size().reset_index(name='No_of_listings') #to know how much properties listed by the host on different neighbour boroughs
host_list_count
# Out:
#   neighbourhood_group  No_of_listings
# 0               Bronx             916
# 1            Brooklyn           18493
# 2           Manhattan           19592
# 3              Queens            5097
# 4       Staten Island             316

# %%
plt.figure(figsize=(5,4))
sns.set(style='darkgrid')
sns.barplot(y=host_list_count['neighbourhood_group'],x=host_list_count['No_of_listings'],palette='Set2')
plt.xlabel('Sum of lists by hosts')
plt.ylabel('Boroughs')
plt.title('No. of host listing on different boroughs', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'No. of host listing on different boroughs')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# The Boroughs and listing by hosts are categorical data. So the best way to visualize is to use horizontal bar chart

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# * We can see that the property listing by hosts is slightly higher in manhattan area as compared to Brooklyn. About **19592** properties are listed by the hosts in Manhattan area
# * The lowest properties listed in airbnb is in staten island which is **316**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Here, we can understand that most of the properties listed are in manhattan area. This is because most of the High income group and billionaires live in this particular borough. It is also most densely populated area so we can conclude that, the rental rate of properties listed in this borough will be significantly higher which we can see from the previous chart. The staten island listing is lower because it is least populated borough based on the information provided by wikipedia.

# %% [markdown]
# #### Chart-3
# ###Percentage of Room-type listed by host in Airbnb

# %%
#finding which room-type is listed more using pie chart
room_type_count = airbnb_df.groupby(['room_type'])['host_name'].count()
room_type_count
# Out:
# room_type
# Entire home/apt    23224
# Private room       20507
# Shared room          683
# Name: host_name, dtype: int64

# %%
palette= sns.color_palette('pastel')
plt.pie(room_type_count, labels=room_type_count.index, colors=palette, autopct='%1.1f%%')
plt.title("Total Percentage of Room-types listed by hosts in Airbnb", fontweight='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# The pie chart to check the percentage of room-type listed by the host in Airbnb

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# * The entire home/apartment listed by host out of 100 is 52.3%. We can state that most of the room types advertised is entire home/apartment
# * The listing of shared home is the least which is only 1.5%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Based on the above figure, we can understand that the most hosts lists the entire home/apartment in airbnb site. Which directly means that hosts prefer to provide entire home/apartment on rent/lease as compared to renting shared room or private room. This probably because they are reluctant to provide private room or shared room for rent. Instead of providing the entire home, if the host is ready to partition the home into private rooms, they might probably get lots of good customers. But a disadvantage is that the in manhattan areas, the high-income groups would prefer to stay in entire apartment.

# %% [markdown]
# #### Chart - 4
# ### Top Hosts with highest number of reviews

# %%
#Filtering the the data not to count 0 as review and sorting them descending to know top 0 host with highest number of review
high_num = airbnb_df[airbnb_df['number_of_reviews']>0].groupby(['host_id','host_name'])['number_of_reviews'].sum().reset_index()
highest = high_num.sort_values(by='number_of_reviews',ascending=False).head(10).reset_index(drop=True)
highest
# Out:
#     host_id                       host_name  number_of_reviews
# 0    344035  Brooklyn&   Breakfast    -Len-               2205
# 1  35524316                    Yasu & Akiko               1971
# 2  37312959                            Maya               1862
# 3  40176101                           Brady               1818
# 4   4734398                              Jj               1798
# 5  26432133                        Danielle               1793
# 6  16677326                  Alex And Zeena               1355
# 7   6885157                           Randy               1346
# 8  23591164                          Angela               1269
# 9  59529529                             Han               1229

# %%
sns.set(style='whitegrid')
sns.pointplot(data=highest, x='number_of_reviews', y='host_name', join=False, palette='Set2')
plt.xlabel('Number of reviews')
plt.ylabel('Host',fontsize=17)
plt.title('Top 10 Host with highest number of reviews', fontweight='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# The point plot is used to show the individual data points without connecting the lines. This is useful as it provides clear view of how each of the hosts has recevied reviews from the customers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# From this chart, we can understand that the **Brooklyn&breakfast** **len** has recevied the most number of reviews from customers compared to other host. This will be easier for other customer to filter the data in airbnb website based on the reviews of the host. Reviews are most important while checking out the property so that the customer can look upon before making purchase for room/apartment.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Here **Brooklyn&breakfast** **len** has the most number of review as compared to other hosts. Not all customers will post the review when they purchase or make payment for the property. The best way to make the customer post review is give additional discounts on next payment, or give good benefits so that it will automatically make the customer post the review which will helpful to look up the data for analysis.

# %% [markdown]
# #### Chart - 5
# ### Geographical ditribution of Neighbourhood groups

# %%
plt.figure(figsize=(9,7))
sns.set(palette='Set1',style='white')
sns.scatterplot(data=airbnb_df, x='latitude', y='longitude', hue='neighbourhood_group')
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Geographical Distribution of listing by Neighbourhood Groups")
plt.legend(fontsize=11)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# I choose scatterplot for geographical distribution of airbnb listing by neighbourhood groups because it is suited for representing individual data points serving latitude and longitude

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# From the above graph, we can understand that **Manhattan** has the most dense area because all the points are closely within the radius. This states that the most of the properties are listed in manhattan. Whereas, the **Staten island** has least densed area. The **Queens** borough has the most scattered area as compared to other boroughs

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# From this insight we can state that the properties listed in Staten island is relatively low because it is the least dense borough in new york city. So getting a propery in staten island would be difficult but also, inexpensive as compared to Manhattan. Also

# %% [markdown]
# #### Chart - 6
# ###Number of last review each year based on different Neighbourhood groups

# %%
#creating a year only column.
airbnb_df['year_of_last_review'] = airbnb_df['last_review'].dt.year

#counting the number of year of last review
reviews_per_year = airbnb_df.groupby(['year_of_last_review']).size().reset_index(name='num_reviews')
reviews_per_year
# Out:
#    year_of_last_review  num_reviews
# 0               2011.0            7
# 1               2012.0           24
# 2               2013.0           45
# 3               2014.0          184
# 4               2015.0         1309
# 5               2016.0         2514
# 6               2017.0         2988
# 7               2018.0         5553
# 8               2019.0        23096

# %%
#creating a line plot graph
plt.figure(figsize=(8,7))
sns.lineplot(data=reviews_per_year, x='year_of_last_review', y='num_reviews', marker='o')
plt.grid()
plt.xlabel('Year of Last Review')
plt.xticks(rotation=45)
plt.ylabel('Number of Reviews')
plt.title('Number of Last added Reviews Over Time', fontweight='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# **Line** **chart** is the best option to find the user trends over time. This chart is suitable for visualization and shows how user review activity trends over time

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# The graph shows the number of last review added by the user each year. From
# 2011 - 2014, the line chart proves that there is steady growth. There is a substantial rise from the year 2018 onwards as we can see in the graph.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Based on the visualization, we can see that there is only a steady rise from 2011- 2014. This is probably because airbnb was formed on 2008 and it wasn't much popular at the period of time. From 2011, user has started putting up the review for different properties and gradually there is a rise from 2015 onwards. This states that airbnb was growing into popular online marketplace for sharing rooms and services to the customers. Also in 2019, we can also see that there is high peak meaning more number of reviews are posted by customer for each properties.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# To find the categorical data of top average rental price between different neighbourhood, Bargraph is best choice.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# The above graph shows that the location fort Wadsworth has the highest average rental price. This is because Fort Wadsworth is situated in

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# From this insight we can state that the properties listed in Staten island is relatively low because it is the least dense borough in new york city. So getting a propery in staten island would be difficult but also, inexpensive as compared to Manhattan. Also

# %% [markdown]
# #### Chart - 6
# ###Top 10 Neighbourhood where host has listed properties in airbnb

# %%
neighbours_ = airbnb_df['neighbourhood'].value_counts().reset_index(name='Counts').rename(columns={'index':'Neighbourhood'}).head(10)
neighbours_
# Out:
#         Neighbourhood  Counts
# 0        Williamsburg    3740
# 1  Bedford-Stuyvesant    3401
# 2              Harlem    2513
# 3            Bushwick    2213
# 4     Upper West Side    1800
# 5      Hell's Kitchen    1763
# 6        East Village    1733
# 7     Upper East Side    1681
# 8       Crown Heights    1431
# 9             Midtown    1211

# %%
plt.figure(figsize=(8,7))
sns.barplot(data=neighbours_, x='Neighbourhood', y='Counts', palette='pastel')
plt.ylabel('Number of listings')
plt.xticks(rotation=75)
plt.title('Top 10 listings on different Neighbourhood',fontweight='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# To find the top 10 highest host listing neighbours, bar graph is suitable so that we can view it as categorical data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# From the above bar graph, Williamsburg neighbourhood has the highest properties listed in Airbnb. About **3918** properties are listed on this particular location.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Williamsburg neighbourhood is located in Brooklyn. One positive impact is that, in Brooklyn, more affordable housing options are available as compared to Manhattan. This is because manhattan is densely populated and most of the higher income groups live there. In this top 10 neighbourhood analysis, most of them are from the groups Brooklyn and Manhattan. Because most number of listing are from the these booth boroughs.

# %% [markdown]
# #### Chart - 7
# ###Price distribution of rooms in Airbnb

# %%
#using histogram to check the price distribution of Airbnb
plt.figure(figsize=(8,7))
sns.histplot(airbnb_df['price'], kde=True, color='indigo')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution of Airbnb', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Price Distribution of Airbnb')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# To find the distribution of Airbnb prices, Histogram is suitable chart as it shows the continuous data which is the price of different rooms

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# The insights which i found from the chart is that majority of property listing in Airbnb falls between **50-200** dollars. The price ranges Between **50-350** dollars for different rooms

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Based on my interpretation, We can assume that most of Property are listed on Airbnb with price range between 50-150 dollars. After **200-250** dollars we can see that there is a drop in graph because there are fewer lists posted by the host in Airbnb due to demand on different Area. As most of the customer prefers afforadable housing options, the hosts would list the property so that customer can afford to rent out the property.

# %% [markdown]
# #### Chart - 8
# ### Total Number of reviews on different room type

# %%
#calculating sum of review on different room type
sum_rev = airbnb_df.groupby('room_type')['reviews_per_month'].sum().reset_index()
sum_rev
# Out:
#          room_type  reviews_per_month
# 0  Entire home/apt           24614.63
# 1     Private room           23893.38
# 2      Shared room             756.35

# %%
#creating Pie Chart
plt.pie(sum_rev['reviews_per_month'],labels=sum_rev['room_type'], autopct='%1.1f%%')
plt.title("Total Sum of Reviews on different room type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# Pie chart will help us to show the distribution of whole divided into categories which is the different room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# Here we can see that the highest review is for the entire home/apartment. Then comes the Private room which is about 48.5%. The shared room has the lowest review which is only 1.5%

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# The above pie chart shows that most customer would prefer entire home or private room. This is because they need themselves the privacy of staying and also family would mostly prefer to have an entire home comapred to shared room. People who are unmarried or single and would pay the lowest rent would prefer to have shared room which is only about 1.5%. Even if they are unmarried or single they would prefer to have a private room because of the comfort, privacy and security to which they stay compared to shared room. That is why most host would list out properties either entire home / private home

# %% [markdown]
# #### Chart - 9
# ### Number of hosts by Neighbourhood group

# %%
# Grouping and removing duplicate host_id to know each unique hosts
num_hosts = airbnb_df.groupby('neighbourhood_group')['host_id'].nunique().reset_index()
num_hosts
# Out:
#   neighbourhood_group  host_id
# 0               Bronx      694
# 1            Brooklyn    14992
# 2           Manhattan    15184
# 3              Queens     3739
# 4       Staten Island      239

# %%
plt.figure(figsize=(6,5))
sns.set(style='ticks')
sns.barplot(data=num_hosts, x='host_id' , y='neighbourhood_group', palette='Set1' )
plt.xlabel('Number of hosts')
plt.ylabel('Neighbourhood Group')
plt.title("Number of Hosts in each neighbourhood group",fontweight='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# To find the number of hosts in each neighbourhood group, Bar graph would be preferable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# Here we can see that the Manhattan has the highest number of active hosts which is about **15184** and brooklyn has the second highest number of active hosts which is 14992.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# As we can see the above graph, Staten Island has very low number of hosts. This is because staten island is not much populous region and it is far away from the main city which is Manhattan. This is probably due to social and economic factors suchs as availability of Stores, Public transportation, active employements etc. Also the rental rates are very low as compared to other groups. Most upper middle class and rich class would prefer to stay in Manhattan or brooklyn so their standard of living improves.

# %% [markdown]
# #### Chart - 10
# ### Correlation Heatmap

# %%
plt.figure(figsize=(13,7))
sns.heatmap(data=airbnb_df.corr(numeric_only=True), annot=True)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 11
# ### Top 10 Average Rental price for different Neighbourhood

# %%
avg_price = airbnb_df.groupby(['neighbourhood','neighbourhood_group'])['price'].mean().reset_index()
sorted_avg_price = avg_price.sort_values(by='price', ascending=False).head(10).reset_index(drop='index')
sorted_avg_price
# Out:
#         neighbourhood neighbourhood_group       price
# 0            Neponsit              Queens  274.666667
# 1         Willowbrook       Staten Island  249.000000
# 2             Tribeca           Manhattan  223.094828
# 3                NoHo           Manhattan  217.383333
# 4        Breezy Point              Queens  213.333333
# 5   Flatiron District           Manhattan  199.050847
# 6        West Village           Manhattan  197.528443
# 7             Midtown           Manhattan  190.532618
# 8  Financial District           Manhattan  185.963415
# 9         Murray Hill           Manhattan  185.131519

# %%
plt.figure(figsize=(8,6))
sns.pointplot(data=sorted_avg_price, x='neighbourhood', y='price', hue='neighbourhood_group',join=False)
plt.grid()
plt.xticks(rotation=45)
plt.xlabel("Neighbourhood")
plt.ylabel("Price")
plt.title("Top 10 Average Rental price for different Neighbourhood", fontweight='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
